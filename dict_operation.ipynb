# %%
with open('Copysample.txt', 'r') as myfile:
    data = myfile.read()
para_dict = {}

#hash 函数另给。
def hash_para(text):
    pass
def chunk_with_para(text,M,loc):
    p = data.split('\n\n')
    for para in p:
        hashtmp = hash_para(p)
        if hashtmp in M:
            M[hashtmp][0].append(loc)
        else:
            M[hashtmp] = [[loc],p]
#字典的Key为此段的hash码，value为list，前一项为文件位置，后一项为段落的内容

# %%
len(p)
# Out:
# 46091

# %%
p
# Out:
# ['The Project Gute.berg EBook of Don Quixote, by Miguel de Cervantes',
#  'This eBook is for the use of anyone anywhere at no cost and with\nalmost no restrictions whatsoever.  You may copy it, give it away or\nre-use it under the terms of the Project Gutenberg License included\nwith this eBook or online at www.gutenberg.net',
#  '\nTitle: Don Quixote',
#  'Author: Miguel de Cervantes Saavedra',
#  'Release Date: July 27, 2004 [EBook #996]',
#  'Language: English',
#  '\n*** START OF THIS PROJECT GUTENBERG EBOOK DON QUIXOTE ***',
#  '',
#  '\nProduced by David Widger',
#  '',
#  '',
#  'DON QUIXOTE',
#  'Complete',
#  'by Miguel de Cervantes [Saavedra]',
#  'Translated by John Ormsby',
#  '',
#  '\nCONTENTS',
#  'Volume I.',
#  'CHAPTER I\nWHICH TREATS OF THE CHARACTER AND PURSUITS OF THE FAMOUS GENTLEMAN\nDON QUIXOTE OF LA MANCHA',
#  'CHAPTER II\nWHICH TREATS OF THE FIRST SALLY THE INGENIOUS DON QUIXOTE MADE\nFROM HOME',
# ...
